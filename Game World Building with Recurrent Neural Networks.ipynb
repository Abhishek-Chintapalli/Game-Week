# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.layers import GRU, Dense, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
# defining character names

character_names = [
    'Harry Potter', 'Hermione Granger', 'Ron Weasley', 'Gandalf', 'Frodo Baggins',
    'Aragorn', 'Bilbo Baggins', 'Luke Skywalker', 'Darth Vader', 'Princess Leia',
    'Jon Snow', 'Arya Stark', 'Tyrion Lannister', 'Daenerys Targaryen', 'Sherlock Holmes',
    'John Watson', 'Hannibal Lecter', 'Clarice Starling', 'Atticus Finch', 'Scout Finch'
]

# create a vocabulary based on the sample names
vocab = sorted(set(''.join(character_names)))
char_to_idx = {char : idx for idx, char in enumerate(vocab)}
idx_to_char = {idx : char for idx, char in char_to_idx.items()}

# convert the names to sequences of indices
sequences = [[char_to_idx[char] for char in name] for name in character_names]

# pad the sequences to the same length
max_name_length = max(len(seq) for seq in sequences)

# print(max_name_length)
padded_sequences = pad_sequences(sequences, maxlen=max_name_length, padding='post')

# create the input and output data
X = padded_sequences[:, :-1]
y = padded_sequences[:, 1:]

# check shape of input sequence
print(X.shape)
# check shape of output sequence
print(y.shape)

# convert our target sequence to one-hot encoded vectors
y_one_hot = to_categorical(y, num_classes=len(vocab))

# defining character for our gru model
vocab_size = len(vocab)
embedding_dim = 32

model = tf.keras.Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim,),
    GRU(128, return_sequences=True),
    Dense(vocab_size, activation='softmax')
])

# compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# train the model
model.fit(X, y_one_hot, epochs=50, verbose=1)
# Out:
# (20, 17)
# (20, 17)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.0176 - loss: 3.5839
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3706 - loss: 3.5654
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3794 - loss: 3.5460
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3765 - loss: 3.5246
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3765 - loss: 3.5001
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3765 - loss: 3.4715
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3765 - loss: 3.4378
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3765 - loss: 3.3977
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3765 - loss: 3.3498
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3765 - loss: 3.2921
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3765 - loss: 3.2225
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3765 - loss: 3.1379
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3765 - loss: 3.0353
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3765 - loss: 2.9120
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3765 - loss: 2.7687
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3765 - loss: 2.6173
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3765 - loss: 2.4929
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3765 - loss: 2.4653
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3765 - loss: 2.5568
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3765 - loss: 2.6073
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3765 - loss: 2.5786
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3765 - loss: 2.5117
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3765 - loss: 2.4479
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3765 - loss: 2.4103
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3765 - loss: 2.3994
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3765 - loss: 2.4039
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3765 - loss: 2.4130
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3765 - loss: 2.4199
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3765 - loss: 2.4218
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3765 - loss: 2.4179
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3765 - loss: 2.4088
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3765 - loss: 2.3957
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3765 - loss: 2.3804
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3765 - loss: 2.3647
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3765 - loss: 2.3507
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3765 - loss: 2.3399
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3765 - loss: 2.3335
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.3765 - loss: 2.3312
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3765 - loss: 2.3314
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3765 - loss: 2.3320
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3765 - loss: 2.3307
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3765 - loss: 2.3265
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3765 - loss: 2.3198
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3765 - loss: 2.3119
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3765 - loss: 2.3044
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3765 - loss: 2.2983
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3765 - loss: 2.2940
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3765 - loss: 2.2911
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3765 - loss: 2.2889
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3765 - loss: 2.2867

# %%
seed = 'a'
seed_idx = [char_to_idx[char] for char in seed]

# map our seed charaters to indexes
seed_idx = [char_to_idx[char] for char in seed]

for _ in range(3):
    temperature = .5
    predicted_probs = model.predict(np.array(seed_idx).reshape(1, -1))[0]
    predicted_probs = predicted_probs[-1]
    
    predicted_probs = np.power(predicted_probs, 1/temperature)
    predicted_probs = predicted_probs / np.sum(predicted_probs)
    
    next_char = np.random.choice(list(char_to_idx.keys()), p=predicted_probs)
    
    seed += next_char
    seed_idx.append(char_to_idx[next_char])

print(seed)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# aifS
